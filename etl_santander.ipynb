# %% [markdown]
# # Santander ETL com Python

# %%
# carregando a url da api santander dev week 2023
sdw2023_api_url = 'https://sdw-2023-prd.up.railway.app'

# %% [markdown]
# ## Extract

# %% [markdown]
# ### Extração da lista de ids de usuário a partir do arquivo CSV.

# %%
import pandas as pd

df = pd.read_csv('SDW2023.csv')
user_ids = df['UserID'].tolist()
print(user_ids)
# Out:
# [12, 13, 14, 15, 16, 17, 18]

# %%
import requests
import json

def get_user(id):
    '''Obten informações do usuário por meio de envio do id'''
    response = requests.get(f'{sdw2023_api_url}/users/{id}')
    return response.json() if response.status_code == 200 else None

users = [user for id in user_ids if (user := get_user(id)) is not None]
print(json.dumps(users, indent=2))
# Out:
# [
#   {
#     "id": 12,
#     "name": "Ronaldo",
#     "account": {
#       "id": 19,
#       "number": "00001-4",
#       "agency": "0032",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 12,
#       "number": "**** **** **** 2313",
#       "limit": 1000.0
#     },
#     "features": [
#       {
#         "id": 9,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 23,
#         "icon": "string",
#         "description": "string"
#       },
#       {
#         "id": 121,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/insurance.svg",
#         "description": "Invista no seu futuro e garanta a seguran\u00e7a financeira."
#       },
#       {
#         "id": 248,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 249,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 970,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Ronaldo, todas estas quest\u00f5es, devidamente ponderadas, levantam d\u00favidas sobre se o entendimento das metas propostas n\u00e3o pode mais se dissociar dos n\u00edveis de motiva\u00e7\u00e3o departamental. "
#       },
#       {
#         "id": 1587,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Ronaldo, investir hoje, colher amanh\u00e3."
#       },
#       {
#         "id": 1588,
#         "icon": "money-mouth-face.svg",
#         "description": "Ronaldo, investimentos: seu passaporte para o sucesso."
#       },
#       {
#         "id": 1589,
#         "icon": "money-mouth-face.svg",
#         "description": "Ronaldo, planeje hoje, invista para sempre."
#       },
#       {
#         "id": 1590,
#         "icon": "money-mouth-face.svg",
#         "description": "Ronaldo, fa\u00e7a seu dinheiro trabalhar por voc\u00ea."
#       },
#       {
#         "id": 1591,
#         "icon": "money-mouth-face.svg",
#         "description": "Ronaldo, construa riqueza com investimentos."
#       }
#     ]
#   },
#   {
#     "id": 13,
#     "name": "anguile",
#     "account": {
#       "id": 20,
#       "number": "00010-8",
#       "agency": "2003",
#       "balance": 500.0,
#       "limit": 1000.0
#     },
#     "card": {
#       "id": 13,
#       "number": "**** **** **** 0112",
#       "limit": 500.0
#     },
#     "features": [
#       {
#         "id": 10,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 24,
#         "icon": "string",
#         "description": "string"
#       },
#       {
#         "id": 122,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/insurance.svg",
#         "description": "Invista seu dinheiro com sabedoria e garanta um futuro promissor."
#       },
#       {
#         "id": 250,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 251,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 971,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "anguile, ainda assim, existem d\u00favidas a respeito de como o desafiador cen\u00e1rio globalizado talvez venha a ressaltar a relatividade dos conhecimentos estrat\u00e9gicos para atingir a excel\u00eancia. "
#       },
#       {
#         "id": 1592,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "anguile, invista agora no seu amanh\u00e3."
#       },
#       {
#         "id": 1593,
#         "icon": "money-mouth-face.svg",
#         "description": "anguile, seguran\u00e7a financeira via investimentos."
#       },
#       {
#         "id": 1594,
#         "icon": "money-mouth-face.svg",
#         "description": "anguile, planeje hoje, invista para sempre."
#       },
#       {
#         "id": 1595,
#         "icon": "money-mouth-face.svg",
#         "description": "anguile, investimentos: seu passaporte para o sucesso."
#       },
#       {
#         "id": 1596,
#         "icon": "money-mouth-face.svg",
#         "description": "anguile, sonhe grande, invista maior."
#       }
#     ]
#   },
#   {
#     "id": 14,
#     "name": "Maria",
#     "account": {
#       "id": 21,
#       "number": "00110-2",
#       "agency": "2003",
#       "balance": 500.0,
#       "limit": 1000.0
#     },
#     "card": {
#       "id": 14,
#       "number": "**** **** **** 0322",
#       "limit": 500.0
#     },
#     "features": [
#       {
#         "id": 11,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 25,
#         "icon": "string",
#         "description": "string"
#       },
#       {
#         "id": 252,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 253,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 972,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Maria, todavia, o novo modelo estrutural aqui preconizado agrega valor ao estabelecimento do levantamento das vari\u00e1veis envolvidas. "
#       },
#       {
#         "id": 1597,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Maria, planeje hoje, invista para sempre."
#       },
#       {
#         "id": 1598,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, investir hoje, colher amanh\u00e3."
#       },
#       {
#         "id": 1599,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, seguran\u00e7a financeira via investimentos."
#       },
#       {
#         "id": 1600,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, invista agora no seu amanh\u00e3."
#       },
#       {
#         "id": 1601,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, investimentos: seu passaporte para o sucesso."
#       }
#     ]
#   },
#   {
#     "id": 15,
#     "name": "Pyterson",
#     "account": {
#       "id": 22,
#       "number": "0001-1",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 15,
#       "number": "1234 1234 1234 1111",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 51,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista hoje, colha amanh\u00e3! #FuturoBrilhante"
#       },
#       {
#         "id": 132,
#         "icon": "\ud83e\udd11",
#         "description": null
#       },
#       {
#         "id": 140,
#         "icon": "\ud83e\udd11",
#         "description": null
#       },
#       {
#         "id": 148,
#         "icon": "\ud83e\udd11",
#         "description": "Pyterson, O futuro \u00e9 hoje: invista para colher amanh\u00e3."
#       },
#       {
#         "id": 156,
#         "icon": "\ud83e\udd11",
#         "description": "Pyterson, Invista hoje, desfrute no futuro."
#       },
#       {
#         "id": 254,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 255,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 973,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pyterson, a certifica\u00e7\u00e3o de metodologias que nos auxiliam a lidar com a consulta aos diversos militantes representa uma abertura para a melhoria dos m\u00e9todos utilizados na avalia\u00e7\u00e3o de resultados. "
#       },
#       {
#         "id": 1602,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pyterson, seu futuro depende dos investimentos."
#       },
#       {
#         "id": 1603,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, construa riqueza com investimentos."
#       },
#       {
#         "id": 1604,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, investir \u00e9 cuidar do seu futuro."
#       },
#       {
#         "id": 1605,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, seu futuro depende dos investimentos."
#       },
#       {
#         "id": 1606,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, fa\u00e7a seu dinheiro trabalhar por voc\u00ea."
#       }
#     ]
#   },
#   {
#     "id": 16,
#     "name": "Pip",
#     "account": {
#       "id": 23,
#       "number": "0002-2",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 16,
#       "number": "1234 1234 1234 2222",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 256,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 257,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 974,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pip, \u00e9 claro que o fen\u00f4meno da internet talvez venha a ressaltar a relatividade da gest\u00e3o inovadora da qual fazemos parte. "
#       },
#       {
#         "id": 1610,
#         "icon": "money-mouth-face.svg",
#         "description": "Pip, fa\u00e7a seu dinheiro trabalhar por voc\u00ea."
#       },
#       {
#         "id": 1607,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pip, invista agora no seu amanh\u00e3."
#       },
#       {
#         "id": 1608,
#         "icon": "money-mouth-face.svg",
#         "description": "Pip, sonhe grande, invista maior."
#       },
#       {
#         "id": 1609,
#         "icon": "money-mouth-face.svg",
#         "description": "Pip, fa\u00e7a seu dinheiro trabalhar por voc\u00ea."
#       },
#       {
#         "id": 1611,
#         "icon": "money-mouth-face.svg",
#         "description": "Pip, construa riqueza com investimentos."
#       }
#     ]
#   },
#   {
#     "id": 17,
#     "name": "Pep",
#     "account": {
#       "id": 24,
#       "number": "0003-3",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 17,
#       "number": "1234 1234 1234 3333",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 258,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 259,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 975,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pep, percebemos, cada vez mais, que o entendimento das metas propostas pode nos levar a considerar a reestrutura\u00e7\u00e3o do sistema de participa\u00e7\u00e3o geral. "
#       },
#       {
#         "id": 1612,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pep, investimentos: seu passaporte para o sucesso."
#       },
#       {
#         "id": 1613,
#         "icon": "money-mouth-face.svg",
#         "description": "Pep, construa riqueza com investimentos."
#       },
#       {
#         "id": 1614,
#         "icon": "money-mouth-face.svg",
#         "description": "Pep, fa\u00e7a seu dinheiro trabalhar por voc\u00ea."
#       },
#       {
#         "id": 1615,
#         "icon": "money-mouth-face.svg",
#         "description": "Pep, investir \u00e9 cuidar do seu futuro."
#       },
#       {
#         "id": 1616,
#         "icon": "money-mouth-face.svg",
#         "description": "Pep, planeje hoje, invista para sempre."
#       }
#     ]
#   },
#   {
#     "id": 18,
#     "name": "Rides",
#     "account": {
#       "id": 25,
#       "number": "0009-9",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 0.0
#     },
#     "card": {
#       "id": 18,
#       "number": "**** **** **** 111",
#       "limit": 0.0
#     },
#     "features": [
#       {
#         "id": 12,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 32,
#         "icon": "string",
#         "description": "string"
#       },
#       {
#         "id": 260,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 261,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 976,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Rides, por conseguinte, o desenvolvimento cont\u00ednuo de distintas formas de atua\u00e7\u00e3o obstaculiza a aprecia\u00e7\u00e3o da import\u00e2ncia das novas proposi\u00e7\u00f5es. "
#       },
#       {
#         "id": 1617,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Rides, construa riqueza com investimentos."
#       },
#       {
#         "id": 1618,
#         "icon": "money-mouth-face.svg",
#         "description": "Rides, investir \u00e9 cuidar do seu futuro."
#       },
#       {
#         "id": 1619,
#         "icon": "money-mouth-face.svg",
#         "description": "Rides, investir \u00e9 cuidar do seu futuro."
#       },
#       {
#         "id": 1620,
#         "icon": "money-mouth-face.svg",
#         "description": "Rides, sonhe grande, invista maior."
#       },
#       {
#         "id": 1621,
#         "icon": "money-mouth-face.svg",
#         "description": "Rides, construa riqueza com investimentos."
#       }
#     ]
#   }
# ]

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Geração de marketing personalizado para casa usuário.

# %%
# carregando a lista com frases motivacionais para investimento (geradas no chat gpt)
f_df = pd.read_csv('markting_bancario.csv')
frases = f_df['frase'].tolist()
print(frases)
# Out:
# ['invista agora no seu amanhã.', 'seu futuro depende dos investimentos.', 'investir hoje, colher amanhã.', 'faça seu dinheiro trabalhar por você.', 'segurança financeira via investimentos.', 'construa riqueza com investimentos.', 'planeje hoje, invista para sempre.', 'investir é cuidar do seu futuro.', 'sonhe grande, invista maior.', 'investimentos: seu passaporte para o sucesso.']

# %%
import random

def frases_news():
    '''Busca aleatória das frases na lista'''
    i = random.randint(0, len(frases)-1)
    return frases[i]

# personalisando as frases para os usuários
for user in users:
    news = f'{user["name"]}, {frases_news()}'
    print(news)
    user['news'].append({
        "icon": "money-mouth-face.svg",
        "description": news
    })
# Out:
# Ronaldo, segurança financeira via investimentos.
# anguile, construa riqueza com investimentos.
# Maria, segurança financeira via investimentos.
# Pyterson, construa riqueza com investimentos.
# Pip, planeje hoje, invista para sempre.
# Pep, investir hoje, colher amanhã.
# Rides, seu futuro depende dos investimentos.

# %% [markdown]
# ## Load

# %% [markdown]
# ### Atualização da lista de novidados (news) de cada usuário na API

# %%
def update_user(user):
    response = requests.put(f'{sdw2023_api_url}/users/{user["id"]}', json=user)
    return True if response.status_code == 200 else False

for user in users:
    success = update_user(user)
    print(f'Usuário {user["name"]} atualizado? {success}!')
# Out:
# Usuário Ronaldo atualizado? True!
# Usuário anguile atualizado? True!
# Usuário Maria atualizado? True!
# Usuário Pyterson atualizado? True!
# Usuário Pip atualizado? True!
# Usuário Pep atualizado? True!
# Usuário Rides atualizado? True!
